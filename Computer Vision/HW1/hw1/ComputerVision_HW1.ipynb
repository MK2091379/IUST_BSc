# %% [markdown]
# # Homework 1
# ## Digital Image Fundamentals (Chapter 2)

# %% [markdown]
# ## Image links:
# Img2.jpg: https://drive.iust.ac.ir/index.php/s/yfxxASNkEiejF9P

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# read image 1
img1 = cv2.imread('Img2.jpg')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

# resize image to 100*100
img1 = cv2.resize(img1, (100,100))

# Image size
print ('Image1 shape: ', img1.shape)
# Out:
# Image1 shape:  (100, 100, 3)

# %% [markdown]
# #### Eq (2-45)
# ![2-45.jpg](data:image/jpeg;base64,...)
#
# #### Table (2-3)
# ![2-3.jpg](data:image/jpeg;base64,...)

# %%
def Transform(img, T_matrix):
    
    rows, cols, _ = ...
    
    # get the coordinates in the form of (0,0),(0,1)...(99,198),(99,199).
    # the shape is (2, rows*cols)
    orig_coord = np.indices((cols, rows)).reshape(2,-1)

    # stack the rows of 1 to form [x,y,1]
    # Hint: use  np.vstack function
    orig_coord_f = ...

    #get the translated matrix
    # Hint: Do not use loops
    transform_coord = ...

    # Change into int type
    transform_coord = transform_coord.astype(int)

    # Keep only the coordinates that fall within the image boundary.
    indices = np.all((transform_coord[1]<rows, transform_coord[0]<cols, 
                      transform_coord[1]>=0, transform_coord[0]>=0), axis=0)
    
    # Create a zeros image and project the points
    output = ...
    output[transform_coord[1][indices], transform_coord[0][indices]] = img[orig_coord[1][indices], orig_coord[0][indices]]

    return output

# %%
# part A
# Transformation Matrix : Scale

# Parameters:

# Matrix:
A = ...

scaled_image = Transform(img1, A)

# %%
fig, axes = plt.subplots(nrows= 1, ncols= 2, figsize=(10,20))

axes[0].imshow(img1)
axes[1].imshow(scaled_image)

plt.show()

# %%
# part B
# Transformation Matrix : Rotate

# Parameters:

# Matrix:
A = ...

rotated_image = Transform(img1, A)

# %%
fig, axes = plt.subplots(nrows= 1, ncols= 2, figsize=(10,20))

axes[0].imshow(img1)
axes[1].imshow(rotated_image)

plt.show()

# %%
# part C
# Transformation Matrix : Translate

# Parameters:

# Matrix:
A = ...

translated_image = Transform(img1, A)

# %%
fig, axes = plt.subplots(nrows= 1, ncols= 2, figsize=(10,20))

axes[0].imshow(img1)
axes[1].imshow(rotated_image)

plt.show()

# %%
# part D
# Transformation Matrix : Combination of some transformation

# Parameters:

# Matrix:
A = ...

rotated_image = Transform(img1, A)

# %%
fig, axes = plt.subplots(nrows= 1, ncols= 2, figsize=(10,20))

axes[0].imshow(img1)
axes[1].imshow(rotated_image)

plt.show()
